# %%
import requests
from requests import Response
youbike_url='https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
try:
    repons:Response=requests.request('GET',youbike_url)
    repons.raise_for_status()
except Exception:
    print("下載錯誤")
else:
    content=repons.text

# %%
from pprint import pprint
pprint(content)

# %%
from pydantic import BaseModel,RootModel

class Station(BaseModel):
    sna:str
    sarea:str
    mday:str
    ar:str
    act:str
    total:int
    available_rent_bike:int
    available_return_bike:int

class Youbikes(RootModel):
    root:list[Station]

youbikes:Youbikes=Youbikes.model_validate_json(content)
youbikes_list=youbikes.model_dump()
pprint(youbikes_list)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 16
#      13 class Youbikes(RootModel):
#      14     root:list[Station]
# ---> 16 youbikes:Youbikes=Youbikes.model_validate_json(content)
#      17 youbikes_list=youbikes.model_dump()
#      18 pprint(youbikes_list)
#
# File ~/.local/lib/python3.11/site-packages/pydantic/main.py:597, in BaseModel.model_validate_json(cls, json_data, strict, context)
#     595 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     596 __tracebackhide__ = True
# --> 597 return cls.__pydantic_validator__.validate_json(json_data, strict=strict, context=context)
#
# ValidationError: 2902 validation errors for Youbikes
# 0.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101001', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 0.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101001', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101002', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101002', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101003', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 2.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101003', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 3.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101004', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 3.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101004', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 4.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101005', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 4.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101005', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 5.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101006', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 5.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101006', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 6.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101007', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 6.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101007', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 7.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101008', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 7.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101008', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 8.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101009', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 8.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101009', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 9.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101010', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 9.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101010', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 10.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101012', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 10.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101012', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 11.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101013', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 11.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101013', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 12.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101014', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 12.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101014', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 13.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101015', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 13.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101015', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 14.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101016', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 14.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101016', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 15.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101018', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 15.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101018', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 16.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101019', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 16.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101019', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 17.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101020', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 17.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101020', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 18.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101021', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 18.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101021', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 19.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101022', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 19.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101022', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 20.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101023', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 20.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101023', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 21.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101024', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 21.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101024', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 22.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101025', 'sna...lable_return_bikes': 96}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 22.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101025', 'sna...lable_return_bikes': 96}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 23.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101026', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 23.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101026', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 24.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101027', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 24.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101027', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 25.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101028', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 25.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101028', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 26.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101029', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 26.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101029', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 27.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101030', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 27.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101030', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 28.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101031', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 28.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101031', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 29.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101032', 'sna...lable_return_bikes': 60}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 29.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101032', 'sna...lable_return_bikes': 60}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 30.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101033', 'sna...lable_return_bikes': 46}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 30.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101033', 'sna...lable_return_bikes': 46}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 31.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101034', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 31.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101034', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 32.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101035', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 32.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101035', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 33.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101036', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 33.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101036', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 34.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101037', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 34.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101037', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 35.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101038', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 35.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101038', 'sna...lable_return_bikes': 27}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 36.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101039', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 36.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101039', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 37.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101040', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 37.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101040', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 38.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101041', 'sna...lable_return_bikes': 39}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 38.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101041', 'sna...lable_return_bikes': 39}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 39.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101042', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 39.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101042', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 40.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101091', 'sna...lable_return_bikes': 32}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 40.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101091', 'sna...lable_return_bikes': 32}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 41.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101092', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 41.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101092', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 42.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101093', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 42.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101093', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 43.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101094', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 43.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101094', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 44.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101095', 'sna...lable_return_bikes': 35}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 44.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101095', 'sna...lable_return_bikes': 35}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 45.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101097', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 45.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101097', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 46.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101098', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 46.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101098', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 47.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101099', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 47.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101099', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 48.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101100', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 48.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101100', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 49.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101101', 'sna...lable_return_bikes': 58}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 49.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101101', 'sna...lable_return_bikes': 58}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 50.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101102', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 50.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101102', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 51.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101103', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 51.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101103', 'sna...ilable_return_bikes': 5}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 52.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101104', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 52.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101104', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 53.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101105', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 53.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101105', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 54.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101107', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 54.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101107', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 55.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101108', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 55.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101108', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 56.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101109', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 56.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101109', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 57.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101110', 'sna...lable_return_bikes': 59}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 57.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101110', 'sna...lable_return_bikes': 59}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 58.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101111', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 58.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101111', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 59.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101113', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 59.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101113', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 60.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101114', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 60.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101114', 'sna...lable_return_bikes': 49}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 61.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101115', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 61.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101115', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 62.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101116', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 62.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101116', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 63.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101117', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 63.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101117', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 64.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101118', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 64.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101118', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 65.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101119', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 65.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101119', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 66.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101120', 'sna...lable_return_bikes': 43}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 66.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101120', 'sna...lable_return_bikes': 43}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 67.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101122', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 67.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101122', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 68.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101123', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 68.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101123', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 69.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101124', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 69.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101124', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 70.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101125', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 70.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101125', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 71.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101126', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 71.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101126', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 72.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101127', 'sna...lable_return_bikes': 44}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 72.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101127', 'sna...lable_return_bikes': 44}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 73.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101128', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 73.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101128', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 74.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101129', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 74.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101129', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 75.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101130', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 75.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101130', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 76.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101131', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 76.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101131', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 77.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101132', 'sna...lable_return_bikes': 53}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 77.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101132', 'sna...lable_return_bikes': 53}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 78.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101133', 'sna...lable_return_bikes': 42}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 78.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101133', 'sna...lable_return_bikes': 42}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 79.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101134', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 79.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101134', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 80.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101135', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 80.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101135', 'sna...lable_return_bikes': 19}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 81.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101136', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 81.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101136', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 82.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101137', 'sna...lable_return_bikes': 50}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 82.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101137', 'sna...lable_return_bikes': 50}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 83.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101138', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 83.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101138', 'sna...lable_return_bikes': 29}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 84.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101139', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 84.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101139', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 85.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101140', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 85.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101140', 'sna...lable_return_bikes': 24}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 86.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101141', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 86.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101141', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 87.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101142', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 87.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101142', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 88.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101143', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 88.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101143', 'sna...lable_return_bikes': 14}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 89.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101144', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 89.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101144', 'sna...lable_return_bikes': 38}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 90.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101145', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 90.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101145', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 91.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101146', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 91.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101146', 'sna...ilable_return_bikes': 8}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 92.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101147', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 92.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101147', 'sna...ilable_return_bikes': 2}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 93.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101148', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 93.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101148', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 94.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101149', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 94.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101149', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 95.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101150', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 95.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101150', 'sna...lable_return_bikes': 31}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 96.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101151', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 96.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101151', 'sna...lable_return_bikes': 20}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 97.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101152', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 97.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101152', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 98.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101153', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 98.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101153', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 99.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101154', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 99.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101154', 'sna...lable_return_bikes': 13}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 100.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101155', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 100.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101155', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 101.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101156', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 101.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101156', 'sna...lable_return_bikes': 47}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 102.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101157', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 102.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101157', 'sna...lable_return_bikes': 16}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 103.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101158', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 103.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101158', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 104.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101159', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 104.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101159', 'sna...lable_return_bikes': 41}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 105.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101160', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 105.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101160', 'sna...ilable_return_bikes': 7}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 106.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101161', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 106.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101161', 'sna...ilable_return_bikes': 6}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 107.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101162', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 107.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101162', 'sna...ilable_return_bikes': 1}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 108.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101163', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 108.available_return_bike
#   Field required [type=missing, input_value={'sno': '500101163', 'sna...ilable_return_bikes': 0}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 109.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500101165', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 109.available_return_bike
# ...
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1414.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119059', 'sna...lable_return_bikes': 67}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1415.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119060', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1415.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119060', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1416.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119061', 'sna...lable_return_bikes': 37}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1416.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119061', 'sna...lable_return_bikes': 37}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1417.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119062', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1417.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119062', 'sna...lable_return_bikes': 11}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1418.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119063', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1418.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119063', 'sna...lable_return_bikes': 25}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1419.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119064', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1419.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119064', 'sna...lable_return_bikes': 28}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1420.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119065', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1420.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119065', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1421.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119066', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1421.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119066', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1422.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119067', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1422.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119067', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1423.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119068', 'sna...lable_return_bikes': 65}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1423.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119068', 'sna...lable_return_bikes': 65}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1424.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119069', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1424.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119069', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1425.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119070', 'sna...lable_return_bikes': 48}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1425.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119070', 'sna...lable_return_bikes': 48}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1426.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119071', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1426.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119071', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1427.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119072', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1427.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119072', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1428.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119074', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1428.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119074', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1429.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119075', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1429.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119075', 'sna...lable_return_bikes': 45}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1430.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119076', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1430.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119076', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1431.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119077', 'sna...lable_return_bikes': 54}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1431.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119077', 'sna...lable_return_bikes': 54}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1432.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119078', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1432.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119078', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1433.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119079', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1433.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119079', 'sna...lable_return_bikes': 12}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1434.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119080', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1434.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119080', 'sna...lable_return_bikes': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1435.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119081', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1435.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119081', 'sna...lable_return_bikes': 26}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1436.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119082', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1436.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119082', 'sna...ilable_return_bikes': 4}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1437.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119083', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1437.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119083', 'sna...lable_return_bikes': 18}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1438.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119084', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1438.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119084', 'sna...lable_return_bikes': 40}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1439.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119085', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1439.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119085', 'sna...ilable_return_bikes': 9}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1440.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119086', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1440.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119086', 'sna...lable_return_bikes': 51}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1441.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119087', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1441.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119087', 'sna...lable_return_bikes': 30}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1442.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119088', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1442.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119088', 'sna...lable_return_bikes': 34}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1443.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119089', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1443.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119089', 'sna...lable_return_bikes': 22}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1444.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119090', 'sna...lable_return_bikes': 37}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1444.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119090', 'sna...lable_return_bikes': 37}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1445.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119091', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1445.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119091', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1446.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119092', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1446.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119092', 'sna...lable_return_bikes': 17}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1447.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119093', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1447.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119093', 'sna...lable_return_bikes': 36}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1448.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119094', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1448.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119094', 'sna...lable_return_bikes': 15}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1449.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119095', 'sna...lable_return_bikes': 32}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1449.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119095', 'sna...lable_return_bikes': 32}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1450.available_rent_bike
#   Field required [type=missing, input_value={'sno': '500119096', 'sna...lable_return_bikes': 92}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
# 1450.available_return_bike
#   Field required [type=missing, input_value={'sno': '500119096', 'sna...lable_return_bikes': 92}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.8/v/missing
