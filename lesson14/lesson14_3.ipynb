# %%
import numpy as np
import pandas as pd

scores=np.random.randint(50,101,size=(50,5))
df1=pd.DataFrame(scores,colums=['國文','英文','數學','地理','探索'])
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 5
#       2 import pandas as pd
#       4 scores=np.random.randint(50,101,size=(50,5))
# ----> 5 df1=pd.DataFrame(scores,colums=['國文','英文','數學','地理','探索'])
#       6 df1
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'colums'

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
df1 = pd.DataFrame(scores,columns=['國文','英文','數學','地理','探索'])
df1
# Out:
#      國文  英文   數學   地理  探索
# 0    81  76   75  100  62
# 1    68  88   51   67  79
# 2    98  92   74   68  69
# 3    73  52  100   99  61
# 4    61  63   68   78  92
# 5    73  70   96   62  94
# 6    75  72   65   86  59
# 7   100  71   79   50  91
# 8    85  89   86   89  59
# 9    88  63   80   54  52
# 10   76  56   67   59  80
# 11   75  84   95   79  60
# 12   76  89   79   73  56
# 13   52  53   75   66  60
# 14   58  72   82   96  82
# 15   93  69   52   66  93
# 16   99  97   69   60  59
# 17   70  75   55   64  90
# 18   97  86   67   72  79
# 19   66  96   58   69  81
# 20   67  64   52   92  95
# 21   61  64   69   57  68
# 22   68  69   84   94  89
# 23   57  71   73   51  94
# 24   83  52   68   81  99
# 25   86  66   98   82  50
# 26   95  90   91   82  98
# 27  100  53   55   97  93
# 28   76  94   79   79  68
# 29   68  66   56   87  87
# 30   58  61   86   94  63
# 31   94  73   98   53  92
# 32   59  96   86   87  83
# 33   80  73   84   59  86
# 34   50  88   88   71  53
# 35   70  80   78   69  93
# 36   96  97   63   60  86
# 37  100  73   73   74  84
# 38   58  54   96  100  54
# 39  100  63   54   53  78
# 40   79  65   90   91  89
# 41   82  88   94   74  83
# 42   58  91   76   74  50
# 43   50  63   97   57  94
# 44   92  97   74   59  96
# 45   94  98   63   54  96
# 46   82  84   77   87  93
# 47   74  84   96   77  57
# 48   67  69   86   96  80
# 49   99  73   51   83  65

# %%
import random
with open('name.txt',encoding='utf-8') as file:
    names_str=file.read()
    display(names_str)
names_list=names_str.split(sep='\n')
names=random.choices(names_list,k=50)
names
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import random
# ----> 2 with open('name.txt',encoding='utf-8') as file:
#       3     names_str=file.read()
#       4     display(names_str)
#
# File ~/.local/lib/python3.11/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'name.txt'

# %%
import numpy as np
import pandas as pd

scores = np.random.randint(50,101,size=(50,5))
df1 = pd.DataFrame(scores,
                   columns=['國文','英文','數學','地理','探索'],
                   index=names)
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 7
#       2 import pandas as pd
#       4 scores = np.random.randint(50,101,size=(50,5))
#       5 df1 = pd.DataFrame(scores,
#       6                    columns=['國文','英文','數學','地理','探索'],
# ----> 7                    index=names)
#       8 df1
#
# NameError: name 'names' is not defined

# %%
#to_numpy()
df1.to_numpy()

# %%
#to_csv()
df1.to_csv('student.csv')
